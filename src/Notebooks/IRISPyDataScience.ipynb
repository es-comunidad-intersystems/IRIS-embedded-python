# %% [markdown]
# # Data Science by using pandas liabrary

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame([[38.0, 2.0, 18.0, 22.0, 21, np.nan],[19, 439, 6, 452, 226,232]],
                  index=pd.Index(['Tumour (Positive)', 'Non-Tumour (Negative)'], name='Actual Label:'),
                  columns=pd.MultiIndex.from_product([['Decision Tree', 'Regression', 'Random'],['Tumour', 'Non-Tumour']], names=['Model:', 'Predicted:']))
df.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_ebfe9">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Model:</th>
#       <th id="T_ebfe9_level0_col0" class="col_heading level0 col0" colspan="2">Decision Tree</th>
#       <th id="T_ebfe9_level0_col2" class="col_heading level0 col2" colspan="2">Regression</th>
#       <th id="T_ebfe9_level0_col4" class="col_heading level0 col4" colspan="2">Random</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Predicted:</th>
#       <th id="T_ebfe9_level1_col0" class="col_heading level1 col0" >Tumour</th>
#       <th id="T_ebfe9_level1_col1" class="col_heading level1 col1" >Non-Tumour</th>
#       <th id="T_ebfe9_level1_col2" class="col_heading level1 col2" >Tumour</th>
#       <th id="T_ebfe9_level1_col3" class="col_heading level1 col3" >Non-Tumour</th>
#       <th id="T_ebfe9_level1_col4" class="col_heading level1 col4" >Tumour</th>
#       <th id="T_ebfe9_level1_col5" class="col_heading level1 col5" >Non-Tumour</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Actual Label:</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ebfe9_level0_row0" class="row_heading level0 row0" >Tumour (Positive)</th>
#       <td id="T_ebfe9_row0_col0" class="data row0 col0" >38.000000</td>
#       <td id="T_ebfe9_row0_col1" class="data row0 col1" >2.000000</td>
#       <td id="T_ebfe9_row0_col2" class="data row0 col2" >18.000000</td>
#       <td id="T_ebfe9_row0_col3" class="data row0 col3" >22.000000</td>
#       <td id="T_ebfe9_row0_col4" class="data row0 col4" >21</td>
#       <td id="T_ebfe9_row0_col5" class="data row0 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_ebfe9_level0_row1" class="row_heading level0 row1" >Non-Tumour (Negative)</th>
#       <td id="T_ebfe9_row1_col0" class="data row1 col0" >19.000000</td>
#       <td id="T_ebfe9_row1_col1" class="data row1 col1" >439.000000</td>
#       <td id="T_ebfe9_row1_col2" class="data row1 col2" >6.000000</td>
#       <td id="T_ebfe9_row1_col3" class="data row1 col3" >452.000000</td>
#       <td id="T_ebfe9_row1_col4" class="data row1 col4" >226</td>
#       <td id="T_ebfe9_row1_col5" class="data row1 col5" >232.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
weather_df = pd.DataFrame(np.random.rand(10,2)*5,
                          index=pd.date_range(start="2021-01-01", periods=10),
                          columns=["Tokyo", "Beijing"])

def rain_condition(v):
    if v < 1.75:
        return "Dry"
    elif v < 2.75:
        return "Rain"
    return "Heavy Rain"

def make_pretty(styler):
    styler.set_caption("Weather Conditions")
    styler.format(rain_condition)
    styler.format_index(lambda v: v.strftime("%A"))
    styler.background_gradient(axis=None, vmin=1, vmax=5, cmap="YlGnBu")
    return styler

weather_df
# Out:
#                Tokyo   Beijing
# 2021-01-01  1.294589  4.895104
# 2021-01-02  2.788282  3.738957
# 2021-01-03  3.579142  2.260500
# 2021-01-04  1.138221  2.717750
# 2021-01-05  2.597716  4.186460
# 2021-01-06  4.038181  4.249678
# 2021-01-07  4.782941  1.605568
# 2021-01-08  1.112428  1.449346
# 2021-01-09  1.020060  4.579985
# 2021-01-10  4.661374  4.476279

# %%
weather_df.loc["2021-01-04":"2021-01-08"].style.pipe(make_pretty)
# Out:
# <style type="text/css">
# #T_f67c0_row0_col0 {
#   background-color: #fafdcf;
#   color: #000000;
# }
# #T_f67c0_row0_col1 {
#   background-color: #65c3bf;
#   color: #000000;
# }
# #T_f67c0_row1_col0 {
#   background-color: #73c8bd;
#   color: #000000;
# }
# #T_f67c0_row1_col1 {
#   background-color: #234fa1;
#   color: #f1f1f1;
# }
# #T_f67c0_row2_col0 {
#   background-color: #225aa6;
#   color: #f1f1f1;
# }
# #T_f67c0_row2_col1 {
#   background-color: #23499e;
#   color: #f1f1f1;
# }
# #T_f67c0_row3_col0 {
#   background-color: #142670;
#   color: #f1f1f1;
# }
# #T_f67c0_row3_col1 {
#   background-color: #e6f5b2;
#   color: #000000;
# }
# #T_f67c0_row4_col0 {
#   background-color: #fbfdd0;
#   color: #000000;
# }
# #T_f67c0_row4_col1 {
#   background-color: #eff9b6;
#   color: #000000;
# }
# </style>
# <table id="T_f67c0">
#   <caption>Weather Conditions</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f67c0_level0_col0" class="col_heading level0 col0" >Tokyo</th>
#       <th id="T_f67c0_level0_col1" class="col_heading level0 col1" >Beijing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f67c0_level0_row0" class="row_heading level0 row0" >Monday</th>
#       <td id="T_f67c0_row0_col0" class="data row0 col0" >Dry</td>
#       <td id="T_f67c0_row0_col1" class="data row0 col1" >Rain</td>
#     </tr>
#     <tr>
#       <th id="T_f67c0_level0_row1" class="row_heading level0 row1" >Tuesday</th>
#       <td id="T_f67c0_row1_col0" class="data row1 col0" >Rain</td>
#       <td id="T_f67c0_row1_col1" class="data row1 col1" >Heavy Rain</td>
#     </tr>
#     <tr>
#       <th id="T_f67c0_level0_row2" class="row_heading level0 row2" >Wednesday</th>
#       <td id="T_f67c0_row2_col0" class="data row2 col0" >Heavy Rain</td>
#       <td id="T_f67c0_row2_col1" class="data row2 col1" >Heavy Rain</td>
#     </tr>
#     <tr>
#       <th id="T_f67c0_level0_row3" class="row_heading level0 row3" >Thursday</th>
#       <td id="T_f67c0_row3_col0" class="data row3 col0" >Heavy Rain</td>
#       <td id="T_f67c0_row3_col1" class="data row3 col1" >Dry</td>
#     </tr>
#     <tr>
#       <th id="T_f67c0_level0_row4" class="row_heading level0 row4" >Friday</th>
#       <td id="T_f67c0_row4_col0" class="data row4 col0" >Dry</td>
#       <td id="T_f67c0_row4_col1" class="data row4 col1" >Dry</td>
#     </tr>
#   </tbody>
# </table>
